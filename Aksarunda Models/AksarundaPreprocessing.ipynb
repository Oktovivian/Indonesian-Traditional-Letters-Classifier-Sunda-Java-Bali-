# %%
import os
from collections import defaultdict
from sklearn.model_selection import train_test_split

# Path dasar
base_path_aksarunda = r'D:\Proyek Aksara\Datasets'
dataset_paths_aksarunda = {
    'aksara_sunda': os.path.join(base_path_aksarunda, 'aksarunda'),
}

# Subfolder yang relevan
relevant_subfolders_aksarunda = {
    'aksara_sunda': ['ka', 'ga', 'nga', 'ca', 'ja', 'nya',
                     'ta', 'da', 'na', 'pa', 'ba', 'ma',
                     'ya', 'ra', 'la', 'wa', 'sa', 'ha',
                     'fa', 'va', 'qa', 'xa', 'za',
                     'kha', 'sya',
                     'a', 'e', 'eu', 'i', 'o', 'u', 'é']
}

# Fungsi untuk memuat path citra dan labelnya
def load_image_paths_labels(base_path_aksarunda, relevant_subfolders_aksarunda):
    image_paths_labels = []
    for label, folder_path in base_path_aksarunda.items():
        for subfolder in relevant_subfolders_aksarunda[label]:
            subfolder_path = os.path.join(folder_path, subfolder)
            if os.path.exists(subfolder_path):
                for filename in os.listdir(subfolder_path):
                    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                        image_path = os.path.join(subfolder_path, filename)
                        image_paths_labels.append((image_path, subfolder))
    return image_paths_labels

# Muat data
image_paths_labels = load_image_paths_labels(dataset_paths_aksarunda, relevant_subfolders_aksarunda)

# Pisahkan path dan label
image_paths, labels = zip(*image_paths_labels)

# Label numeric
label_map = {label: idx for idx, label in enumerate(relevant_subfolders_aksarunda['aksara_sunda'])}
numeric_labels = [label_map[label] for label in labels]

# Pisahkan data menjadi train dan test (70:30)
train_paths, test_paths, train_labels, test_labels = train_test_split(
    image_paths, numeric_labels, test_size=0.3, stratify=numeric_labels, random_state=42
)

# %%
import shutil

# Utility function to split data
def split_data(base_path_aksarunda, output_base_path_aksarunda, split_ratio=0.7):
    for label, folder_path in base_path_aksarunda.items():
        for subfolder in relevant_subfolders_aksarunda[label]:
            subfolder_path = os.path.join(folder_path, subfolder)
            if os.path.isdir(subfolder_path):
                files = [f for f in os.listdir(subfolder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
                train_files, test_files = train_test_split(files, test_size=1-split_ratio, random_state=42)

                # Create train and test directories
                train_output_dir = os.path.join(output_base_path_aksarunda, 'train', subfolder)
                test_output_dir = os.path.join(output_base_path_aksarunda, 'test', subfolder)
                os.makedirs(train_output_dir, exist_ok=True)
                os.makedirs(test_output_dir, exist_ok=True)

                for file in train_files:
                    shutil.copy(os.path.join(subfolder_path, file), os.path.join(train_output_dir, file))
                for file in test_files:
                    shutil.copy(os.path.join(subfolder_path, file), os.path.join(test_output_dir, file))

# Apply the split
output_base_path_aksarunda = r'D:\Proyek Aksara\Datasets_split_aksarunda'
split_data(dataset_paths_aksarunda, output_base_path_aksarunda)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Path dataset split
train_dir = os.path.join(output_base_path_aksarunda, 'train')
test_dir = os.path.join(output_base_path_aksarunda, 'test')

# ImageDataGenerator untuk augmentasi dan preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Buat generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='sparse'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='sparse'
)
# Out:
# Found 14140 images belonging to 32 classes.
# Found 6084 images belonging to 32 classes.

# %%
classes = sorted(os.listdir(train_dir))

# Tampilkan kelas
print("Kelas yang ada dalam dataset:")
for idx, cls in enumerate(classes):
    print(f"{idx + 1}. {cls}")
# Out:
# Kelas yang ada dalam dataset:
# 1. a
# 2. ba
# 3. ca
# 4. da
# 5. e
# 6. eu
# 7. fa
# 8. ga
# 9. ha
# 10. i
# 11. ja
# 12. ka
# 13. kha
# 14. la
# 15. ma
# 16. na
# 17. nga
# 18. nya
# 19. o
# 20. pa
# 21. qa
# 22. ra
# 23. sa
# 24. sya
# 25. ta
# 26. u
# 27. va
# 28. wa
# 29. xa
# 30. ya
# 31. za
# 32. é

# %%
import os

output_base_path_aksarunda = r'D:\Proyek Aksara\Datasets_split_aksarunda'

# Mengumpulkan label dari struktur output
def get_labels_from_output(output_base_path):
    labels = {}
    for split_folder in ['train', 'test']:  # Iterasi melalui folder train dan test
        split_path = os.path.join(output_base_path, split_folder)
        for label in os.listdir(split_path):
            label_path = os.path.join(split_path, label)
            if os.path.isdir(label_path):
                labels[label] = split_folder  # Menyimpan label split (train/test) untuk setiap folder
    return labels

# Memanggil fungsi untuk mendapatkan label dari struktur output
output_labels = get_labels_from_output(output_base_path_aksarunda)

# Menampilkan label untuk setiap subfolder di dalam direktori train atau test
for label, split in output_labels.items():
    print(f"Folder '{label}' di dalam direktori '{split}' dilabeli sebagai: {label}")
# Out:
# Folder 'a' di dalam direktori 'test' dilabeli sebagai: a
# Folder 'ba' di dalam direktori 'test' dilabeli sebagai: ba
# Folder 'ca' di dalam direktori 'test' dilabeli sebagai: ca
# Folder 'da' di dalam direktori 'test' dilabeli sebagai: da
# Folder 'e' di dalam direktori 'test' dilabeli sebagai: e
# Folder 'eu' di dalam direktori 'test' dilabeli sebagai: eu
# Folder 'fa' di dalam direktori 'test' dilabeli sebagai: fa
# Folder 'ga' di dalam direktori 'test' dilabeli sebagai: ga
# Folder 'ha' di dalam direktori 'test' dilabeli sebagai: ha
# Folder 'i' di dalam direktori 'test' dilabeli sebagai: i
# Folder 'ja' di dalam direktori 'test' dilabeli sebagai: ja
# Folder 'ka' di dalam direktori 'test' dilabeli sebagai: ka
# Folder 'kha' di dalam direktori 'test' dilabeli sebagai: kha
# Folder 'la' di dalam direktori 'test' dilabeli sebagai: la
# Folder 'ma' di dalam direktori 'test' dilabeli sebagai: ma
# Folder 'na' di dalam direktori 'test' dilabeli sebagai: na
# Folder 'nga' di dalam direktori 'test' dilabeli sebagai: nga
# Folder 'nya' di dalam direktori 'test' dilabeli sebagai: nya
# Folder 'o' di dalam direktori 'test' dilabeli sebagai: o
# Folder 'pa' di dalam direktori 'test' dilabeli sebagai: pa
# Folder 'qa' di dalam direktori 'test' dilabeli sebagai: qa
# Folder 'ra' di dalam direktori 'test' dilabeli sebagai: ra
# Folder 'sa' di dalam direktori 'test' dilabeli sebagai: sa
# Folder 'sya' di dalam direktori 'test' dilabeli sebagai: sya
# Folder 'ta' di dalam direktori 'test' dilabeli sebagai: ta
# Folder 'u' di dalam direktori 'test' dilabeli sebagai: u
# Folder 'va' di dalam direktori 'test' dilabeli sebagai: va
# Folder 'wa' di dalam direktori 'test' dilabeli sebagai: wa
# Folder 'xa' di dalam direktori 'test' dilabeli sebagai: xa
# Folder 'ya' di dalam direktori 'test' dilabeli sebagai: ya
# Folder 'za' di dalam direktori 'test' dilabeli sebagai: za
# Folder 'é' di dalam direktori 'test' dilabeli sebagai: é

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping


# Path dataset split
train_dir = os.path.join(output_base_path_aksarunda, 'train')
test_dir = os.path.join(output_base_path_aksarunda, 'test')

# ImageDataGenerator untuk augmentasi dan preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Buat generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='sparse'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='sparse'
)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(512, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(len(relevant_subfolders_aksarunda['aksara_sunda']), activation='softmax')  
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#early stopping for avoid overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train model
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = test_generator.samples // test_generator.batch_size

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=test_generator,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)

# Evaluasi model
test_loss, test_acc = model.evaluate(test_generator)
print(f'Akurasi pada data pengujian: {test_acc:.2f}')
# Out:
# Found 14140 images belonging to 32 classes.
# Found 6084 images belonging to 32 classes.
# c:\Users\p\miniconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# c:\Users\p\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 272s 600ms/step - accuracy: 0.0296 - loss: 3.4684 - val_accuracy: 0.0359 - val_loss: 3.4652
# Epoch 2/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.0625 - loss: 3.4592 - val_accuracy: 0.0000e+00 - val_loss: 3.4710
# Epoch 3/50
# c:\Users\p\miniconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 172s 386ms/step - accuracy: 0.0367 - loss: 3.4652 - val_accuracy: 0.0359 - val_loss: 3.4651
# Epoch 4/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 119us/step - accuracy: 0.0938 - loss: 3.4634 - val_accuracy: 0.0000e+00 - val_loss: 3.4763
# Epoch 5/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 150s 338ms/step - accuracy: 0.0358 - loss: 3.4656 - val_accuracy: 0.0359 - val_loss: 3.4651
# Epoch 6/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 98us/step - accuracy: 0.0625 - loss: 3.4689 - val_accuracy: 0.0000e+00 - val_loss: 3.4760
# Epoch 7/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 149s 336ms/step - accuracy: 0.0347 - loss: 3.4656 - val_accuracy: 0.0359 - val_loss: 3.4651
# Epoch 8/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 96us/step - accuracy: 0.0625 - loss: 3.4613 - val_accuracy: 0.0000e+00 - val_loss: 3.4694
# Epoch 9/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 148s 335ms/step - accuracy: 0.0352 - loss: 3.4653 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 10/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.0625 - loss: 3.4644 - val_accuracy: 0.0000e+00 - val_loss: 3.4786
# Epoch 11/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 149s 336ms/step - accuracy: 0.0345 - loss: 3.4654 - val_accuracy: 0.0357 - val_loss: 3.4651
# Epoch 12/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step - accuracy: 0.0938 - loss: 3.4546 - val_accuracy: 0.2500 - val_loss: 3.4376
# Epoch 13/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 159s 358ms/step - accuracy: 0.0368 - loss: 3.4651 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 14/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.0938 - loss: 3.4531 - val_accuracy: 0.0000e+00 - val_loss: 3.4750
# Epoch 15/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 168s 378ms/step - accuracy: 0.0334 - loss: 3.4655 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 16/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.0000e+00 - loss: 3.4726 - val_accuracy: 0.0000e+00 - val_loss: 3.4772
# Epoch 17/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 172s 387ms/step - accuracy: 0.0333 - loss: 3.4657 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 18/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 119us/step - accuracy: 0.0938 - loss: 3.4595 - val_accuracy: 0.0000e+00 - val_loss: 3.4766
# Epoch 19/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 165s 372ms/step - accuracy: 0.0347 - loss: 3.4654 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 20/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.0000e+00 - loss: 3.4653 - val_accuracy: 0.0000e+00 - val_loss: 3.4774
# Epoch 21/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 181s 409ms/step - accuracy: 0.0361 - loss: 3.4653 - val_accuracy: 0.0359 - val_loss: 3.4651
# Epoch 22/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - accuracy: 0.0625 - loss: 3.4562 - val_accuracy: 0.0000e+00 - val_loss: 3.4454
# Epoch 23/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 221s 496ms/step - accuracy: 0.0340 - loss: 3.4656 - val_accuracy: 0.0357 - val_loss: 3.4651
# Epoch 24/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 216us/step - accuracy: 0.0312 - loss: 3.4703 - val_accuracy: 0.2500 - val_loss: 3.4345
# Epoch 25/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 229s 516ms/step - accuracy: 0.0348 - loss: 3.4652 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 26/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 163us/step - accuracy: 0.0312 - loss: 3.4632 - val_accuracy: 0.0000e+00 - val_loss: 3.4746
# Epoch 27/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 247s 556ms/step - accuracy: 0.0356 - loss: 3.4653 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 28/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 222us/step - accuracy: 0.1250 - loss: 3.4496 - val_accuracy: 0.0000e+00 - val_loss: 3.4749
# Epoch 29/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 240s 539ms/step - accuracy: 0.0357 - loss: 3.4655 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 30/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 185us/step - accuracy: 0.0938 - loss: 3.4632 - val_accuracy: 0.0000e+00 - val_loss: 3.4748
# Epoch 31/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 243s 547ms/step - accuracy: 0.0355 - loss: 3.4654 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 32/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 120us/step - accuracy: 0.0312 - loss: 3.4680 - val_accuracy: 0.0000e+00 - val_loss: 3.4766
# Epoch 33/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 243s 546ms/step - accuracy: 0.0356 - loss: 3.4657 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 34/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 218us/step - accuracy: 0.0312 - loss: 3.4523 - val_accuracy: 0.0000e+00 - val_loss: 3.4740
# Epoch 35/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 256s 576ms/step - accuracy: 0.0370 - loss: 3.4652 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 36/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 137us/step - accuracy: 0.0625 - loss: 3.4638 - val_accuracy: 0.0000e+00 - val_loss: 3.4779
# Epoch 37/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 256s 573ms/step - accuracy: 0.0349 - loss: 3.4657 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 38/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - accuracy: 0.0312 - loss: 3.4672 - val_accuracy: 0.0000e+00 - val_loss: 3.4788
# Epoch 39/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 244s 551ms/step - accuracy: 0.0377 - loss: 3.4651 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 40/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 231us/step - accuracy: 0.0625 - loss: 3.4637 - val_accuracy: 0.0000e+00 - val_loss: 3.4770
# Epoch 41/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 243s 542ms/step - accuracy: 0.0375 - loss: 3.4651 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 42/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 1s 276us/step - accuracy: 0.0312 - loss: 3.4709 - val_accuracy: 0.0000e+00 - val_loss: 3.4790
# Epoch 43/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 237s 528ms/step - accuracy: 0.0352 - loss: 3.4650 - val_accuracy: 0.0359 - val_loss: 3.4651
# Epoch 44/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 241us/step - accuracy: 0.0938 - loss: 3.4615 - val_accuracy: 0.0000e+00 - val_loss: 3.4407
# Epoch 45/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 219s 487ms/step - accuracy: 0.0354 - loss: 3.4651 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 46/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 249us/step - accuracy: 0.0938 - loss: 3.4619 - val_accuracy: 0.0000e+00 - val_loss: 3.4802
# Epoch 47/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 242s 546ms/step - accuracy: 0.0340 - loss: 3.4656 - val_accuracy: 0.0357 - val_loss: 3.4651
# Epoch 48/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 189us/step - accuracy: 0.0000e+00 - loss: 3.4675 - val_accuracy: 0.2500 - val_loss: 3.4367
# Epoch 49/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 221s 497ms/step - accuracy: 0.0356 - loss: 3.4655 - val_accuracy: 0.0359 - val_loss: 3.4650
# Epoch 50/50
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 0.0625 - loss: 3.4611 - val_accuracy: 0.0000e+00 - val_loss: 3.4770
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.0321 - loss: 3.4658
# Akurasi pada data pengujian: 0.04
